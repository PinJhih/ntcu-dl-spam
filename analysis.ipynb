# %%
import pandas as pd
import numpy as np

df = pd.read_csv("./data/enron_spam_data.csv")
df.fillna({'Message': 'missing', 'Subject': 'missing'}, inplace=True)
df
# Out:
#        Message ID                                            Subject  \
# 0               0                       christmas tree farm pictures
# 1               1                           vastar resources , inc .
# 2               2                       calpine daily gas nomination
# 3               3                                         re : issue
# 4               4                          meter 7268 nov allocation
# ...           ...                                                ...
# 33711       33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712       33712  all prescript medicines are on special . to be...
# 33713       33713              the next generation online pharmacy .
# 33714       33714                     bloow in 5 - 10 times the time
# 33715       33715                   dear sir , i am interested in it
#
#                                                  Message Spam/Ham        Date
# ...

# %%
df['m_len'] = df['Message'].str.len()
df['s_len'] = df['Subject'].str.len()

# %%
def remove_outliers(series):
    mean = series.mean()
    std = series.std()

    lower_bound = mean - 3 * std
    upper_bound = mean + 3 * std

    series_filtered = series[(series >= lower_bound) & (series <= upper_bound)]
    removed = len(series) - len(series_filtered)
    print("Remove", removed, "in", len(series), "items.")

    return series_filtered

def print_statics(series):
    print("mean:", series.mean())
    print("std: ", series.std())
    print("quantile")
    print(series.quantile([0.25, 0.5, 0.75, 1]))
    print("===============================")

# %%
m_len = df['m_len']
s_len = df['s_len']

print("Message String Length Statics")
print_statics(m_len)
print("Subject String Length Statics")
print_statics(s_len)
# Out:
# Message String Length Statics
# mean: 1470.4002254122672
# std:  4283.488205759253
# quantile
# 0.25       308.00
# 0.50       675.00
# 0.75      1514.25
# 1.00    228353.00
# Name: m_len, dtype: float64
# ...
# Subject String Length Statics
# mean: 34.634238937003204
# std:  42.57313008747207
# quantile
# 0.25      19.0
# 0.50      30.0
# 0.75      44.0
# 1.00    3153.0
# Name: s_len, dtype: float64
# ...

# %%
m_len = remove_outliers(m_len)
s_len = remove_outliers(s_len)

print("Message String Length Statics after removeing outliers\n")
print_statics(m_len)
print("Subject String Length Statics after removeing outliers\n")
print_statics(s_len)
# Out:
# Remove 192 in 33716 items.
# Remove 81 in 33716 items.
# Message String Length Statics after removeing outliers
#
# mean: 1243.905440878177
# std:  1627.384912062123
# quantile
# 0.25      306.75
# 0.50      668.00
# 0.75     1494.00
# 1.00    14151.00
# Name: m_len, dtype: float64
# ...
# Subject String Length Statics after removeing outliers
#
# mean: 33.58254794113275
# std:  19.607496836689517
# quantile
# 0.25     19.0
# 0.50     30.0
# 0.75     44.0
# 1.00    159.0
# Name: s_len, dtype: float64
# ...
